# %%
from IPython.core.display import display,HTML
display(HTML('<style>div.prompt {display:none}</style>'))
display(HTML('<style>div.input{display:none;}</style>'))
# Out:
# <style>div.prompt {display:none}</style>
# <style>div.input{display:none;}</style>

# %% [markdown]
# <body style="background-image: url('imgs/background.png');"></body>
# <img src="imgs/transparent2.png" width="70%" /><br>
#
# <font size="5" style="color: red"><b><center>**NOTICE**: We're looking for more speakers!!<br> If you would like to present, fill out our super quick <a href="https://www.surveymonkey.co.uk/r/JX7NQBR">speakers form</a> </center></b></font><br>
#
#
# <font size="6"><b><center> Click a poster below to view the webinar recording. </center></b></font><br>
# <font style="color: gray"><i><center> Note that the talk on <b>"Responding to disasters and enhancing 3D images with<br> synthetic datasets"</b> is in two parts. The link for part 2 is under the poster image.
# </center></i></font>
#
#
#
# <table style="width:100%">
#     <tr>
#         <td>
#             <p>
#             <img src="imgs/CNN_colloq_small.png", style="width: 300px"/>
#             </p>
#         </td>
#         <td>
#             <p>
#           <a href="https://web.microsoftstream.com/video/242e7ba6-d489-45d7-b2d6-4227fdbce290" title="GANS talk">
#             <img src="imgs/GANS_big_withID.png", style="width: 300px"/>
#           </a>
#             </p>
#         </td>
#         <td>
#             <p>
#               <a href="https://web.microsoftstream.com/video/33b1b6a6-5f51-4d96-9a6e-ef2f3aca862b" title="VAE talk">
#                 <img src="imgs/VAES_medium.png", style="width: 300px"/>
#               </a>
#             </p>
#         </td>
#         <td>
#             <p>
#               <a href="https://web.microsoftstream.com/video/afbe6805-d02f-4e9c-86a8-fe04d5a73ac5" title="Cancer research and Asteroids talk">
#                 <img src="imgs/27_05_20.png", style="width: 300px"/>
#               </a>
#             </p>
#         </td>
#     <tr>
#         <td>
#                   <font size="3"><b>
#                   <center> No video for this event </center>
#                   <center><a href="https://gla.sharepoint.com/:b:/s/MLinScience/EWrDbC1GPShPuk1t04QEUQwBPCauWxHauFqjb80HB-l1qA?e=V6aAT7">Slides - C. Webster</a></center>
#                   <center><a href="https://gla.sharepoint.com/:b:/s/MLinScience/EfLWBZ5jhH1AvH_g-2P3bHkBSYiu2mLD-OrnJekmMZh-eQ?e=6xArIb">Slides - S. Johnson</a></center></b></font>
#         </td>
#         <td>
#                   <font size="3">
#                   <b>
#                   <center><a  href="https://web.microsoftstream.com/video/242e7ba6-d489-45d7-b2d6-4227fdbce290">Video - GANs</a></center>
#                   <center><a href="https://gla.sharepoint.com/:b:/s/MLinScience/EUfB1Q1ZVvBOg0TNAmscdLUBkSidfefGbI7JAive17Sccw?e=01J3oD">Slides - A. C. Quiros</a></center>
#                   <center><a href="https://gla.sharepoint.com/:b:/s/MLinScience/EYto6L88aSNNkieoY6HlfcoBm4Q7qWX4rZUeFSqD8fsS5Q?e=JhfAgL">Slides - V. Kapitany</a></center>
#                   <center><a href="https://gla.sharepoint.com/:b:/s/MLinScience/EaFCQBOoix9LjRyBrt0z9XMBLIhkOJ60iZ1A4N2U3kLIPA?e=AYQN5z">Slides - C. Higham</a></center></b></font>
#         </td>
#         <td>
#                   <font size="3">
#                   <b>
#                   <center><a  href="https://web.microsoftstream.com/video/33b1b6a6-5f51-4d96-9a6e-ef2f3aca862b">Video - VAEs</a></center>
#                   <center><a href="https://gla.sharepoint.com/:b:/s/MLinScience/EVxh1NTfhUFOsiovHEPE6cwBwL0qs-DFIfjDSiJnqYpRyw?e=De2zKv">Slides - B. Jensen</a></center>
#                   <center><a href="https://gla.sharepoint.com/:b:/s/MLinScience/EWQk1sFZkMZJrBaLWtVsTyYB6_Xs9n3y2Sg5PSzteZqpew?e=NdDkx1">Slides - F. Tonolini</a></center>
#                   <center><a href="https://gla.sharepoint.com/:b:/s/MLinScience/EbHs907Re35KsHN8XCxJm5MB4g0ECBbqW8dtjqi4s-BIHQ?e=FZUODS">Slides - C. Daube</a></center></b></font>
#         </td>
#         <td>
#                   <font size="3">
#                   <b>
#                   <center><a  href="https://web.microsoftstream.com/video/afbe6805-d02f-4e9c-86a8-fe04d5a73ac5">Video - Cancer research and Asteroids</a></center>
#                   <center><a href="https://gla.sharepoint.com/:b:/s/MLinScience/EVddCvvsDrJMpI7zihry4eUBJIeM5SLbmK0Bz-denIV9Ew?e=rOf6Ie">Slides - C. Walsh</a></center>
#                   <center><a href="https://gla.sharepoint.com/:b:/s/MLinScience/Eb0JkIPAwYBEmvX2_PjiplgBPGna3M-KyLFuiwOEk463ow?e=Dz3vjH">Slides - G. Viavattene</a></center>
#                   </b></font>
#         </td>
#     </tr>
#     <tr>
#         <td>
#             <p>
#               <a href="https://web.microsoftstream.com/video/b3b6e5b5-9bf8-45f5-a048-ed4b84662113" title="Disasters talk">
#                 <img src="imgs/MLiS 10_06_20 small.png", style="width: 300px"/></a>
#             </p>
#         </td>
#         <td>
#             <p>
#               <a href="https://web.microsoftstream.com/video/78f36ec5-fc05-49db-8f23-6038766eb981" title="GP talk">
#                 <img src="imgs/MLiS 22_07_20 small.png", style="width: 300px"/>
#               </a>
#             </p>
#         </td>
#         <td>
#             <p>
#               <a href="https://web.microsoftstream.com/video/526e5100-a3ed-4c40-a40a-2452c66f8181" title="Unsupervised talk">
#                 <img src="imgs/MLiS 26_08_20 small.png", style="width: 300px"/>
#               </a>
#             </p>
#         </td>
#         <td>
#             <p>
#               <a href="https://web.microsoftstream.com/video/54e8934b-666f-4681-8379-22347dacaf8c" title="Rescources @UoG">
#                 <img src="imgs/resources_small.png", style="width: 300px"/>
#               </a>
#             </p>
#         </td>
#     </tr>
#     <tr>
#         <td>
#                <font size="3">
#                   <b><center><a href="https://web.microsoftstream.com/video/b3b6e5b5-9bf8-45f5-a048-ed4b84662113">Video Pt.1: A. Hepburn</a></center>
#                   <center><a href="https://web.microsoftstream.com/video/48ee6ed7-31ae-4d96-8d89-0fa4ddca26dc">Video Pt.2: X. Gu</a></center></b></font>
#                <font size="3">
#                    <b><center><a href="https://gla.sharepoint.com/:b:/s/MLinScience/EZw1NuByI_FGuR9AsLLKOesB8CJ4orVjOEZEEwskhg1Mrg?e=HRRgNw">Slides - A. Hepburn</a></center>
#                    </b></font>
#         </td>
#         <td>
#                 <font size="3">
#                 <b>
#                 <center><a  href="https://web.microsoftstream.com/video/78f36ec5-fc05-49db-8f23-6038766eb981">Video - GPs</a></center>
#                 <center><a href="https://gla.sharepoint.com/:b:/s/MLinScience/EX_wLSRRY69PvWYcJXKc-aABd3FlALLNeWQrc0v5fmOgLw?e=Wyhmfh">Slides - D. Dalton</a></center>
#                   <center><a href="https://gla.sharepoint.com/:b:/s/MLinScience/EdjSVUhphElNtQ7o1FO8l0EBECQ3RiCGnRXri8oaPO-ESw?e=vVQ4dM">Slides - A. Uhrenholt</a></center>
#                   </b></font>
#         </td>
#         <td>
#                <font size="3">
#                   <b><center><a href="https://web.microsoftstream.com/video/526e5100-a3ed-4c40-a40a-2452c66f8181">Video Pt.1: J. Lindsay</a></center>
#                   <center><a href="https://web.microsoftstream.com/video/12f9ef42-9d0f-4594-894d-9a937fd346b9">Video Pt.2: J. Mitton</a></center></b></font>
#                <font size="3">
#                    <b><center><a href="https://gla.sharepoint.com/:b:/s/MLinScience/EZA_UftjlcJEv0geHSklnfYByxx4s8V8wQ9DLutmqTDXjg?e=2f3bSf">Slides - J. Lindsay</a></center>
#                    </b></font>
#                 <font size="3">
#                    <b><center><a href="https://gla.sharepoint.com/:b:/s/MLinScience/EZEQrbZFthFJp5aqtGHW4uYBrkNaPamRHgEUyAe2yjfStA?e=wfxtfm">Slides - J. Mitton</a></center>
#                    </b></font>
#         </td>
#         <td>
#                <font size="3">
#                    <b>
#                    <center><a  href="https://web.microsoftstream.com/video/54e8934b-666f-4681-8379-22347dacaf8c">Video - Resources</a></center>
#                    <center>click <a href="https://gla.sharepoint.com/:b:/s/MLinScience/EaLk9-NKLrBClNtG6db4yi0Bwh1cdPhxddpw3EGgQPq-JQ?e=CPQpgE">here</a> for links to resources (Updated:02/11/2020)</center>
#                    </b></font>
#        </td>
# </tr>
#
# <tr>
#     <td>
#         <p>
#           <a href="https://web.microsoftstream.com/video/ab9f32cf-2d02-42c6-ab85-fd3064a758c0" title="RNNs">
#             <img src="imgs/RNNs_03_02_21_small.png", style="width: 300px"/>
#           </a>
#         </p>
#     </td>
#     <td>
#         <p>
#           <a href="https://web.microsoftstream.com/video/20f41366-2602-445a-ac62-b006809dfd78" title="RL">
#             <img src="imgs/03_03_21_small.png", style="width: 300px"/>
#           </a>
#         </p>
#     </td>
#     <td>
#         <p>
#           <a href="https://web.microsoftstream.com/video/26e86768-a6bf-49ce-b5c2-603b5dfc7e31" title="EdgeML">
#             <img src="imgs/07_04_21.png", style="width: 300px"/>
#           </a>
#         </p>
#     </td>
#     <td>
#         <p>
#           <a href="https://web.microsoftstream.com/video/f5f8029e-d2f1-4721-a93d-e4dfcf9f799f" title="Interpretability">
#             <img src="imgs/12_05_21_small.png", style="width: 300px"/>
#           </a>
#         </p>
#     </td>
# </tr>
# <tr>
#       <td>
#            <font size="3">
#               <b><center><a href="https://web.microsoftstream.com/video/ab9f32cf-2d02-42c6-ab85-fd3064a758c0">Video - RNNs</a></center></b></font>
#       </td>
#       <td>
#            <font size="3">
#               <b><center><a href="https://web.microsoftstream.com/video/20f41366-2602-445a-ac62-b006809dfd78">Video - RL</a></center></b></font>
#       </td>
#       <td>
#            <font size="3">
#               <b><center><a href="https://web.microsoftstream.com/video/26e86768-a6bf-49ce-b5c2-603b5dfc7e31">Video - EdgeML</a></center></b></font>
# </b></font>
#       </td>
#       <td>
#            <font size="3">
#               <b><center><a href="https://web.microsoftstream.com/video/f5f8029e-d2f1-4721-a93d-e4dfcf9f799f">Video - Interpretability</a></center></b></font>
# <font size="3">
#                    <b><center><a href="https://gla.sharepoint.com/:b:/s/MLinScience/EXeRcHdEN29Cu2QMTWRLU04BmU7WEW5Z9yOz2xPmeDBWEA?e=6XQl7Y">Slides - Y. Jones</a></center>
#                    </b></font>
#                 <font size="3">
#                    <b><center><a href="https://gla.sharepoint.com/:b:/s/MLinScience/EXxK0cRyQm9DnumI_rjGutIBYcytI7Zj-F33O5tdOSki4g?e=ZgZtrK">Slides - A. Hepburn</a></center>
#                    </b></font>
#       </td>
# </tr>
# </table>
#
# <br><br><br><br>
#
#
# <table style="width:100%">
#     <tr>
#         <td  width="60%">
#             <div style="float: left"><a class="twitter-timeline" data-width="1000" data-height="400" data-theme="light" href="https://twitter.com/MLinScience?ref_src=twsrc%5Etfw">Tweets by MLinScience</a> <script async src="https://platform.twitter.com/widgets.js" charset="utf-8"></script></div>
#         </td>
#         <td>
#             <font size="6"><div style="text-align:center">Follow us on <a href="https://twitter.com/MLinScience">Twitter</a></div></font>
#         </td>
#     </tr>
# </table>
# <br><br><br><br>
# <table>
#     <tr>
#         <td><div style="text-align: left"><font size="6">
#             <b>Sign up to our mailing list</b></font><br><font size="3"><br>
#             1. Go to UoG sympa page: <a href="https://www.gla.ac.uk/myglasgow/it/emaillists/">https://www.gla.ac.uk/myglasgow/it/emaillists/</a><br>
#             <i><p style="color: red">Note: You must be on a UoG server, for off-campus access use a VPN <a href="https://www.gla.ac.uk/myglasgow/it/vpn/">https://www.gla.ac.uk/myglasgow/it/vpn/</a></p></i><br>
#             2. Log in<br><br>
#             3. Search "mlinscience"<br><br>
#             4. Click subscribe and enter email address
#             </font></div>
#         </td>
#         <td width="60%">
#             <img style="float: right;" src=imgs/signup.gif width="800px"/>
#         </td>
#     </tr>
# </table>
# <br><br><br><br>
# <table>
#     <tr>
#         <td width="50%">
#             <a href="https://join.slack.com/t/glasgowuniver-ocy8095/shared_invite/zt-f3cstte8-MB54XfMedOzlle3rjDZDZA" title="Join Slack Workspace"><img  style="float: left;" src=imgs/slack.png width="600px"/></a>
#         </td>
#         <td>
# <font size=6><div style="text-align: center"> Join our Machine Learning<br> in Science <a href="https://join.slack.com/t/glasgowuniver-ocy8095/shared_invite/zt-f3cstte8-MB54XfMedOzlle3rjDZDZA">slack workspace</a></div></font>
#         </td>
#     </tr>
# </table>
# <br><br><br><br>
# <table>
#     <tr>
#         <td>
#         <font size=6><div style="text-align: center"> Subscribe to our <a href="https://samoa.dcs.gla.ac.uk/events/series.jsp?series=168">samoa</a> events page</div></font>
#         </td>
#         <td width="60%">
#             <a href="https://samoa.dcs.gla.ac.uk/events/series.jsp?series=168" title="samoa events page"><img  style="float: left;" src=imgs/Uog.png height="60px"/></a>
#         </td>
#     </tr>
#     <tr>
#
# </table>
#
#
# <br><br><br><br>
# <font size=5><center><b> Interested in speaking at one of the seminars?</b><br><br> Fill out this quick <a href="https://www.surveymonkey.co.uk/r/JX7NQBR">speakers form</a><br> or email us at <i>scieng-mlinscience@glasgow.ac.uk</i> and we'll be in touch!</center></font>

# %% [markdown]
# <font style="color: gray" size="3"><center><i>Our aim is to create a <b>community</b> of researchers who can <b>share knowledge</b><br> about machine learning to <b>enhance research, develop skills</b> relevant <br>for industry and encourage <b>interdisciplinary collaboration</b>.</i></center></font>
