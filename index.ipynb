# %% [markdown]
# # <center> Click the poster to view the video </center>
# <i><center> Note that the talk on <b>"Responding to disasters and enhancing 3D images with<br> synthetic datasets"</b> is in two parts. The link for part 2 is under the poster image.
# </center></i>
#
#
#
# <table style="width:100%">
#     <tr>
#         <td>
#             <p>
#             <img src="imgs/CNN_colloq_small.png", style="width: 300px"/>
#             </p>
#         </td>
#         <td>
#             <p>
#           <a href="https://uofglasgow.zoom.us/rec/share/usp3FvKo5nJJGZXw6V7wGZUgHJzrT6a813cZ-_sIyU0FbgbFlUCJppEOziqIvY-H?startTime=1587556943000" title="GANS talk">
#             <img src="imgs/GANS_big_withID.png", style="width: 300px"/>
#           </a>
#             </p>
#         </td>
#         <td>
#             <p>
#               <a href="https://uofglasgow.zoom.us/rec/play/tcd5cb_7rG03Tted4QSDU6VwW9W1LPqs13Qe-6cKzE6wVXBRZlWvY7MTYuqVpwAP8zIo7_5z4X7c-GET?startTime=1589371201000" title="VAE talk">
#                 <img src="imgs/VAES_medium.png", style="width: 300px"/>
#               </a>
#             </p>
#         </td>
#         <td>
#             <p>
#               <a href="https://youtu.be/t2NGgebOY9s" title="Cancer research and Asteroids talk">
#                 <img src="imgs/27_05_20.png", style="width: 300px"/>
#               </a>
#             </p>
#         </td>
#     <tr>
#         <td>
#                   <font size="3"><b>
#                   <center> No video for this event </center>
#                   <center><a href="slides/2020_03_11_CNN_Tutorial_Carol_Webster.pdf">Slides - C. Webster</a></center>
#                   <center><a href="slides/Steven_Johnson_ML_Seminar_Slides.pdf">Slides - S. Johnson</a></center></b></font>
#         </td>
#         <td>
#                   <font size="3">
#                   <b><center><a href="slides/AC_Quiros_Intro_to_GANs.pdf">Slides - A. C. Quiros</a></center>
#                   <center><a href="slides/V_Kapitany_SRGAN_for_FLIM.pdf">Slides - V. Kapitany</a></center>
#                   <center><a href="slides/CF_Higham_GANs_in_Science.pdf">Slides - C. Higham</a></center></b></font>
#         </td>
#         <td>
#                   <font size="3">
#                   <b><center><a href="slides/B_Jensen_VAE_Overview.pdf">Slides - B. Jensen</a></center>
#                   <center><a href="slides/F_Tonolini_cVAE.pdf">Slides - F. Tonolini</a></center>
#                   <center><a href="slides/C_Daube_Interpretable_Generative_Model_Of_3D_Faces.pdf">Slides - C. Daube</a></center></b></font>
#         </td>
#         <td>
#                   <font size="3">
#                   <b><center><a href="slides/C_Walsh_unets_cancer_bud_segmentation.pdf">Slides - C. Walsh</a></center>
#                   <center><a href="ml_in_science_giulia.pdf">Slides - G. Viavattene</a></center>
#                   </b></font>
#         </td>
#     </tr>
#     <tr>
#         <td>
#             <p>
#               <a href="https://youtu.be/IXPga5pNBvQ" title="Disasters talk">
#                 <img src="imgs/MLiS 10_06_20 small.png", style="width: 300px"/></a>
#             </p>
#         </td>
#         <td>
#             <p>
#               <a href="https://uofglasgow.zoom.us/rec/play/6JMuc7qpq203HIaR5ASDV_J4W466eKmsh3NN-vIOmk-zASZXY1WkY7ATa7fFzKn3bipjpp1fYjX2E2SY" title="GP talk">
#                 <img src="imgs/MLiS 22_07_20 small.png", style="width: 300px"/>
#               </a>
#             </p>
#         </td>
#     </tr>
#     <tr>
#         <td>
#                <font size="3">
#                   <b><center><a href="https://youtu.be/IXPga5pNBvQ">Video Pt.1: A. Hepburn</a></center>
#                   <center><a href="https://youtu.be/3h3z5XfYYY0">Video Pt.2: X. Gu</a></center></b></font>
#                <font size="3">
#                    <b><center><a href="slides/AHepburn-Responding-Disasters-Talk.pdf">Slides - A. Hepburn</a></center>
#                    </b></font>
#         </td>
#         <td>
#                 <font size="3">
#                     <b><center><a href="slides/gp_presentation_slides.pdf">Slides - D. Dalton</a></center>
#                   </b></font>
#         </td>
#
# </tr>
# </table>
#
# <br><br><br><br>
#
#
#
# <table style="width:100%">
#     <tr>
#         <td>
#             <div style="float: left"><a class="twitter-timeline" data-width="800" data-height="400" data-theme="light" href="https://twitter.com/MLinScience?ref_src=twsrc%5Etfw">Tweets by MLinScience</a> <script async src="https://platform.twitter.com/widgets.js" charset="utf-8"></script></div>
#         </td>
#         <td>
#             <font size="6"><div style="text-align:center">Follow us on <a href="https://twitter.com/MLinScience">Twitter</a></div></font>
#         </td>
#     </tr>
# </table>
# <br><br><br><br>
# <table>
#     <tr>
#         <td><div style="text-align: left"><font size="6">
#             <b>Sign up to our mailing list</b></font><br><font size="3"><br>
#             1. Go to UoG sympa page: <a href="https://www.gla.ac.uk/myglasgow/it/emaillists/">https://www.gla.ac.uk/myglasgow/it/emaillists/</a><br>
#             <i><p style="color: red">Note: You must be on a UoG server, for off-campus access use a VPN <a href="https://www.gla.ac.uk/myglasgow/it/vpn/">https://www.gla.ac.uk/myglasgow/it/vpn/</a></p></i><br>
#             2. Log in<br><br>
#             3. Search "mlinscience"<br><br>
#             4. Click subscribe and enter email address
#             </font></div>
#         </td>
#         <td width="70%">
#             <img style="float: right;" src=imgs/signup.gif width="800px"/>
#         </td>
#     </tr>
# </table>
# <br><br><br><br>
# <table>
#     <tr>
#         <td width="50%">
#             <a href="https://join.slack.com/t/glasgowuniver-ocy8095/shared_invite/zt-f3cstte8-MB54XfMedOzlle3rjDZDZA" title="Join Slack Workspace"><img  style="float: left;" src=imgs/slack.png width="600px"/></a>
#         </td>
#         <td>
# <font size=6><div style="text-align: center"> Join our Machine Learning in Science <a href="https://join.slack.com/t/glasgowuniver-ocy8095/shared_invite/zt-f3cstte8-MB54XfMedOzlle3rjDZDZA">slack workspace</a></div></font>
#         </td>
#     </tr>
# </table>
# <br><br><br><br>
# <table>
#     <tr>
#         <td>
#         <font size=6><div style="text-align: center"> Subscribe to our <a href="https://samoa.dcs.gla.ac.uk/events/series.jsp?series=168">samoa</a> events page</div></font>
#         </td>
#         <td width="50%">
#             <a href="https://samoa.dcs.gla.ac.uk/events/series.jsp?series=168" title="samoa events page"><img  style="float: left;" src=imgs/Uog.jpg height="60px"/></a>
#         </td>
#     </tr>
# </table>
#
# <br><br><br><br>
# <font size=5><center><b> Interested in speaking at one of the seminars?</b><br><br> Fill out this quick <a href="https://www.surveymonkey.co.uk/r/JX7NQBR">speakers form</a><br> or email us at <i>scieng-mlinscience@glasgow.ac.uk</i> and we'll be in touch!</center></font>
